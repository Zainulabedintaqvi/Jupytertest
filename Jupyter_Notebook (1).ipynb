# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio <h1>

# %% [markdown]
# **Syed Zain Ul Abedin**
#     <br>Data Science Engineer

# %% [markdown]
# *I am interested in data science because I love to play with data*

# %% [markdown]
# <h3> This Code is just for learning Purpose. Through this Assignment we are learning how to create Jupyter Notebook and make it easy to understand </h3>

# %%
import matplotlib.pyplot as plt
x = [22, 34, 56]
y = [23, 45, 65]
plt.plot(x, y)
plt.xlabel('Xaxis')
plt.ylabel('y axes')
plt.title('Testing')
plt.show()

# %% [markdown]
# This is for learning purpose
